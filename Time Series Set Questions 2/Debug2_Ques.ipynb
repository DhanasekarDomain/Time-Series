# %% [markdown]
# # Q1.AttributeError

# %%
import pandas as pd

df = pd.DataFrame({'Date': ['2023-01-01', '2023-01-02', '2023-01-03'],
                   'Sales': [100, 120, 130]})

missing_sales = df['Sales'].isnull().sum()
print(missing_sales)
# Out:
# 0

# %% [markdown]
# # Q2.TypeError

# %%
df['Date'] = pd.to_datetime(df['Date'])

df = df.set_index('Date')

monthly_mean = df.resample('M').mean()
print(monthly_mean)
# Out:
#                  Sales
# Date
# 2023-01-31  116.666667
# C:\Users\kalas\AppData\Local\Temp\ipykernel_10500\3100172331.py:5: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_mean = df.resample('M').mean()

# %% [markdown]
# # Q3.ValueError

# %%
import pandas as pd
import numpy as np
data = {
    'Date': pd.date_range(start='2023-01-01', periods=10, freq='D'),
    'Passengers': [100, 120, np.nan, 140, 135, np.nan, 150, 160, 170, np.nan]
}

df = pd.DataFrame(data)
print("Original Data:\n", df)
df['Passengers'] = df['Passengers'].fillna(0).astype(int)
print ("Final Data:\n", df)
# Out:
# Original Data:
#          Date  Passengers
# 0 2023-01-01       100.0
# 1 2023-01-02       120.0
# 2 2023-01-03         NaN
# 3 2023-01-04       140.0
# 4 2023-01-05       135.0
# 5 2023-01-06         NaN
# 6 2023-01-07       150.0
# 7 2023-01-08       160.0
# 8 2023-01-09       170.0
# 9 2023-01-10         NaN
# Final Data:
#          Date  Passengers
# 0 2023-01-01         100
# 1 2023-01-02         120
# 2 2023-01-03           0
# 3 2023-01-04         140
# 4 2023-01-05         135
# 5 2023-01-06           0
# 6 2023-01-07         150
# 7 2023-01-08         160
# 8 2023-01-09         170
# 9 2023-01-10           0

# %% [markdown]
# # Q4.KeyError

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# # Q4.Solution

# %%
print(df.columns)  
df['Date'] = pd.to_datetime(df['Date'])
print(df)
# Out:
# Index(['Date', 'Passengers'], dtype='object')
#         Date  Passengers
# 0 2023-01-01         100
# 1 2023-01-02         120
# 2 2023-01-03           0
# 3 2023-01-04         140
# 4 2023-01-05         135
# 5 2023-01-06           0
# 6 2023-01-07         150
# 7 2023-01-08         160
# 8 2023-01-09         170
# 9 2023-01-10           0

# %% [markdown]
# # Q5.ImportError

# %%
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# # Q6. KeyError

# %%
import pandas as pd
import numpy as np

dates=pd.date_range(start='2020-01-01', periods=12, freq='MS')

data = {
    'MonthStart': dates,
    'Sales': np.random.randint(100, 500, size=12),
    'Revenue': np.random.randint(1000, 5000, size=12),
    'Expenses': np.random.randint(500, 2000, size=12)
}

df = pd.DataFrame(data)

print(df)
# Out:
#    MonthStart  Sales  Revenue  Expenses
# 0  2020-01-01    471     4190      1582
# 1  2020-02-01    417     3571      1727
# 2  2020-03-01    484     3742       940
# 3  2020-04-01    107     3522      1149
# 4  2020-05-01    123     2135      1721
# 5  2020-06-01    457     3307      1916
# 6  2020-07-01    190     2399      1151
# 7  2020-08-01    157     1499      1545
# 8  2020-09-01    494     2092      1791
# 9  2020-10-01    333     2820       623
# 10 2020-11-01    476     1387      1552
# 11 2020-12-01    146     2259       532
